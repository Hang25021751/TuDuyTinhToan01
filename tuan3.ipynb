# %%
n = int(input("nhap vao so nguyen n:"))
print("cac chu so dao nguoc la:", str(n)[::-1])
# Out:
# cac chu so dao nguoc la: 986543

# %%
a,b =map(int,input("nhap vao hai so:").split())
a=a^b 
b= a^b 
a= a^b 
print(a,b)
# Out:
# 0 8

# %%
n = int(input("nhap vao so nguyen:"))
if n&(n-1)==0:
    print("n la luy thua cua 2")
else: 
    print("n khong phai la luy thua cua 2")
# Out:
# n la luy thua cua 2

# %%
m,n =map(float,input("nhap vao hai so: ").split())
t=m/n
import math 
# math.floor() : làm tròn xuống 
print(math.floor(t))
# Out:
# 1

# %%
m,n = map(float,input("nhap vao hai so:").split())
import math 
t = m/n 
# math.ceil(): làm tròn lên 
print(math.ceil(t))
# Out:
# 10

# %%
a,b = map(int,input("nhap vao hai so:").split())
if a<0 and b<0 :
    print("YES")
else:
    print("NO")
# Out:
# YES

# %%
a = input("nhap vao mot chuoi chu cai thuong:")
b = input("nhap vao mot chuoi chu cai thuong:")
if len(a)>len(b):
    print("True")
else:
    print("False")
# Out:
# False

# %%
a,b,c = map(int,input("nhap vao 3 so nguyen duong:").split())
if a+b>c and b+c>a and a+c>b:
   print("yes")
else: 
   print("no")
# Out:
# no

# %%
number = list(map(int,input("nhap vao 4 so nguyen:").split()))
print("so nguyen lon nhat trong 4 so:",max(number))
# Out:
# so nguyen lon nhat trong 4 so: 3123

# %%
a,b,c = map(int,input("nhap vao so nguyen duong:").split())
if a+b>c and a+c>b and b+c>a:
    if a==b or a==c or b== c:
       print("la tam giac can ")
    elif a==b==c:
        print("la tam giac deu")
    else:
        print("la tam giac thuong")
else: 
    print("khong phai la tam giac")
# Out:
# khong phai la tam giac

# %%
n = int(input("nhap vao so nguyen duong la so nam:"))
if (n >0) and (n%4==0 and n%100!=0) or (n%400==0):
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
a = float(input("so kWh dien tieu thu:"))
if a<= 50:
    t = a*1500
elif 51<=a<=100:
    t = 50*1500 + (a-50)*2000   
else:
    t = 50*1500 + 50*2000 + (a-100)*3000
print("tien dien la:",t)
# Out:
# tien dien la: 235000.0

# %%
# phuong trinh ax+b=0 
a,b = map(float,input("nhap vao so thuc:").split())
if a==0 and b!=0 :
    print("phuong trinh vo nghiem")
elif a==0 and b==0:
    print("phuong trinh vo so nghiem")
else:
    x= -b/a 
    print(f"nghiem cua phuong trinh la :{x:.2f}")
# Out:
# nghiem cua phuong trinh la :-430.87

# %%
x = float(input("nhap vao diem trung binh:"))
if x>=8.0: 
    print("gioi")
elif 6.5<= x <8.0: 
    print("kha")
elif 5.0<= x < 6.5:
    print("trung binh")
else:
    print("yeu")
# Out:
# kha
