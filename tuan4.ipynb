# %%
n = int(input("nhap vao mot so nguyen:"))
i=1
tong=0
while i<=n:
    tong+=i
    i+=1

print("tong la:",tong)
# Out:
# tong la: 28

# %%
n=-1
while n<=0:
    n = int(input())
for i in range(2,n):
    if n%i==0:
        print("false")
        break
    else:
        print("true")
# Out:
# true
# true
# true

# %%
n = int(input("nhap vao so nguyen:"))
m= 1 
for i in range(1,n+1):
    m*=i
print("ket qua",m)
# Out:
# ket qua 720

# %%
n = abs(int(input("nhap vao so nguyen n:")))
t = 0 
if n == 0:
    print("1")
else: 
    while n!=0:
         t+=1
         n//=10
    print(t)
# Out:
# 5

# %%
n =  int(input("nhap vao so nguyen duong n:"))
m = list (map(int,input("nhap vao day so gom n so nguyen:").split()))
for i in m :
    if i ==42: 
        print("I've found the meaning of life")
        break
    else:
        print("It's a joke")
# Out:
# It's a joke
# It's a joke
# It's a joke
# I've found the meaning of life

# %%
def t(n):
    if n<2:
        return False
    for i in range(2,int(n)**0.5+1):
        if n%2==0:
            break 
        else:
            print("True")
tong=0 
a,b =map (int,input("nhap vao :").split())
for i in range(a,b+1):
    if t(i)=="True":
       tong+=i
print(tong)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 12
#      10 a,b =map (int,input("nhap vao :").split())
#      11 for i in range(a,b+1):
# ---> 12     if t(i)=="True":
#      13        tong+=i
#      14 print(tong)
#
# Cell In[12], line 4, in t(n)
#       2 if n<2:
#       3     return False
# ----> 4 for i in range(2,int(n)**0.5+1):
#       5     if n%2==0:
#       6         break
#
# TypeError: 'float' object cannot be interpreted as an integer
